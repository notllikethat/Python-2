# %% [markdown]
# # Python-2 test
# ## Task 1.
# *(4 points)*
# You have some dataset describing concentrations of five algae metabolites. For each algae
# there is species name, its genus and its group.
# * Using pandas library find the average concentration of each of the metabolite in each
# aglae genus.
# * Visualize the result using seaborn library.

# %%
import pandas as pd
import seaborn as sns

# %%
algae_matabolites = pd.read_csv("metabolites.csv")

algae_matabolites
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# 5  3.343707    1.432514
# 6  2.740165    2.829016
# 7  3.242090    2.245538
# 8  3.947968    4.817804
# 9  3.414961    2.432526

# %%
df = pd.melt(algae_matabolites, id_vars = ['species', 'genus', 'group'], var_name = 'metabolite', value_name = 'value')
df
# Out:
#                  species        genus  group  metabolite     value
# 0      Fucus_vesiculosus        Fucus  brown     sucrose  3.001472
# 1    Saccharina_japonica   Saccharina  brown     sucrose  6.731070
# 2         Fucus_serratus        Fucus  brown     sucrose  3.276870
# 3        Fucus_distichus        Fucus  brown     sucrose  6.786996
# 4      Cladophora_fracta   Cladophora  green     sucrose  3.861470
# 5    Cladophora_compacta   Cladophora  green     sucrose  5.712284
# 6    Cladophora_gracilis   Cladophora  green     sucrose  2.452623
# 7       Palmaria_palmata     Palmaria    red     sucrose  0.704580
# 8   Saccharina_latissima   Saccharina  brown     sucrose  1.636122
# 9    Ascophyllum_nodosum  Ascophyllum  brown     sucrose  6.825467
# 10     Fucus_vesiculosus        Fucus  brown      alanin  3.711498
# 11   Saccharina_japonica   Saccharina  brown      alanin  1.255251
# 12        Fucus_serratus        Fucus  brown      alanin  0.346431
# 13       Fucus_distichus        Fucus  brown      alanin  6.641303
# 14     Cladophora_fracta   Cladophora  green      alanin  1.648450
# 15   Cladophora_compacta   Cladophora  green      alanin  3.461692
# 16   Cladophora_gracilis   Cladophora  green      alanin  6.881024
# 17      Palmaria_palmata     Palmaria    red      alanin  3.176440
# 18  Saccharina_latissima   Saccharina  brown      alanin  5.793163
# 19   Ascophyllum_nodosum  Ascophyllum  brown      alanin  0.875429
# 20     Fucus_vesiculosus        Fucus  brown     citrate  5.004262
# 21   Saccharina_japonica   Saccharina  brown     citrate  5.621499
# 22        Fucus_serratus        Fucus  brown     citrate  1.216767
# 23       Fucus_distichus        Fucus  brown     citrate  6.423606
# 24     Cladophora_fracta   Cladophora  green     citrate  6.940588
# 25   Cladophora_compacta   Cladophora  green     citrate  3.082826
# 26   Cladophora_gracilis   Cladophora  green     citrate  5.841520
# 27      Palmaria_palmata     Palmaria    red     citrate  5.573905
# 28  Saccharina_latissima   Saccharina  brown     citrate  1.071920
# 29   Ascophyllum_nodosum  Ascophyllum  brown     citrate  5.253527
# 30     Fucus_vesiculosus        Fucus  brown     glucose  2.548459
# 31   Saccharina_japonica   Saccharina  brown     glucose  6.013219
# 32        Fucus_serratus        Fucus  brown     glucose  3.623225
# 33       Fucus_distichus        Fucus  brown     glucose  2.272724
# 34     Cladophora_fracta   Cladophora  green     glucose  2.316955
# 35   Cladophora_compacta   Cladophora  green     glucose  3.343707
# 36   Cladophora_gracilis   Cladophora  green     glucose  2.740165
# 37      Palmaria_palmata     Palmaria    red     glucose  3.242090
# 38  Saccharina_latissima   Saccharina  brown     glucose  3.947968
# 39   Ascophyllum_nodosum  Ascophyllum  brown     glucose  3.414961
# 40     Fucus_vesiculosus        Fucus  brown  oleic_acid  6.405165
# 41   Saccharina_japonica   Saccharina  brown  oleic_acid  4.156700
# 42        Fucus_serratus        Fucus  brown  oleic_acid  0.304573
# 43       Fucus_distichus        Fucus  brown  oleic_acid  3.393203
# 44     Cladophora_fracta   Cladophora  green  oleic_acid  2.528886
# 45   Cladophora_compacta   Cladophora  green  oleic_acid  1.432514
# 46   Cladophora_gracilis   Cladophora  green  oleic_acid  2.829016
# 47      Palmaria_palmata     Palmaria    red  oleic_acid  2.245538
# 48  Saccharina_latissima   Saccharina  brown  oleic_acid  4.817804
# 49   Ascophyllum_nodosum  Ascophyllum  brown  oleic_acid  2.432526

# %%
statistics = df.groupby(['genus', 'metabolite'])[['value']].mean()

statistics
# Out:
#                            value
# genus       metabolite
# Ascophyllum alanin      0.875429
#             citrate     5.253527
#             glucose     3.414961
#             oleic_acid  2.432526
#             sucrose     6.825467
# Cladophora  alanin      3.997055
#             citrate     5.288311
#             glucose     2.800276
#             oleic_acid  2.263472
#             sucrose     4.008792
# Fucus       alanin      3.566411
#             citrate     4.214878
#             glucose     2.814803
#             oleic_acid  3.367647
#             sucrose     4.355112
# Palmaria    alanin      3.176440
#             citrate     5.573905
#             glucose     3.242090
#             oleic_acid  2.245538
#             sucrose     0.704580
# Saccharina  alanin      3.524207
#             citrate     3.346710
#             glucose     4.980594
#             oleic_acid  4.487252
#             sucrose     4.183596

# %%
statistics.plot(kind ='bar', figsize = (15,15))

# %% [markdown]
# ## Task 2.
#
# *(4 points)*
#
# You have noticed that map() function returns something different than list. Simply saying, it
# returns iterator. Up to this point, we used list(map(...)) syntax, but remember that iterators in
# some cases are more preferable than lists.
# This task is devoted to understanding how iterators work.
# * First create iterator via my_iter = map(lambda ...) construction that takes [1,2,3,4,5,6]
# and returns True if there is no remainder after division of the list’s element on 3 and
# returns False otherwise.
# * In infinite loop proceed the iterator using the next() function on it. Observe the appearing
# error in this loop.
# * Write except block catching this particular error.
# * Based on this usecase try to understand in which cases iterators might be more
# preferable than lists.

# %%
my_iter = map(lambda x: True if x % 3 == 0 else False, 
              [1, 2, 3, 4, 5, 6])

# %%
next(my_iter)
# Out:
# True

# %%
while True:
    i = next(my_iter)
    print(i)
# Out:
# False
# False
# True
# False
# False
# True
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# <ipython-input-9-9eedb66f40cd> in <module>
#       1 while True:
# ----> 2     i = next(my_iter)
#       3     print(i)
#
# StopIteration:

# %%
while True:
    try:
        i = next(my_iter)
        print(i)
    except StopIteration:
        break
# Out:
# False
# False
# True
# False
# False
# True

# %% [markdown]
# ### Task 3
#
# *(4 points)*
#
# In this task, you need to use API of numbersapi.com site.
# You are given a set of numbers: 17, 45, 999, 1883. For each of the numbers, you need to find
# out if there is an interesting mathematical or historical fact about it. The answer should contain
# these facts marked as “math” or “hist”.

# %%
import requests

# proxies = {
#   'http': 'http://134.209.29.120',
#   'https': 'http://82.119.170.106',
# }

# requests.get('http://example.org')

requests.get('http://example.org', proxies=proxies)
# Out:
# <Response [200]>

# %%
numbers = [17, 45, 999, 1883]

# %%
urls = ["http://numbersapi.com/" + str(number) + "/math?json=true" for number in numbers]
urls
# Out:
# ['http://numbersapi.com/17/math?json=true',
#  'http://numbersapi.com/45/math?json=true',
#  'http://numbersapi.com/999/math?json=true',
#  'http://numbersapi.com/1883/math?json=true']
